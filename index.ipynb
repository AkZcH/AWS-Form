# %% [markdown]
# # Data Cleaning & Wrangling

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Reading the original dataset

# %%
df = pd.read_csv('cardekho.csv')
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  mileage(km/ltr/kg)  engine  \
# 0  Individual       Manual   First Owner               23.40  1248.0
# 1  Individual       Manual  Second Owner               21.14  1498.0
# 2  Individual       Manual   Third Owner               17.70  1497.0
# 3  Individual       Manual   First Owner               23.00  1396.0
# 4  Individual       Manual   First Owner               16.10  1298.0
#
#   max_power  seats
# 0        74    5.0
# 1    103.52    5.0
# 2        78    5.0
# 3        90    5.0
# ...

# %% [markdown]
# ### Dropping All The Columns

# %%
df_withoutcolumn = pd.read_csv('cardekho.csv', header=None)
df_withoutcolumn.head()
# Out:
#                              0     1              2          3       4   \
# 0                          name  year  selling_price  km_driven    fuel
# 1        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 3      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 4     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
#
#             5             6             7                   8       9   \
# 0  seller_type  transmission         owner  mileage(km/ltr/kg)  engine
# 1   Individual        Manual   First Owner                23.4  1248.0
# 2   Individual        Manual  Second Owner               21.14  1498.0
# 3   Individual        Manual   Third Owner                17.7  1497.0
# 4   Individual        Manual   First Owner                23.0  1396.0
#
#           10     11
# 0  max_power  seats
# 1         74    5.0
# 2     103.52    5.0
# ...

# %% [markdown]
# ### Dropping 1 Column
#  We drop the 'year' column

# %%
df_dropcolumn = df.drop('year', axis=1)
df_dropcolumn.head()
# Out:
#                            name  selling_price  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI         450000     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition         370000     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi         158000     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel         225000     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII         130000     120000  Petrol  Individual
#
#   transmission         owner  mileage(km/ltr/kg)  engine max_power  seats
# 0       Manual   First Owner               23.40  1248.0        74    5.0
# 1       Manual  Second Owner               21.14  1498.0    103.52    5.0
# 2       Manual   Third Owner               17.70  1497.0        78    5.0
# 3       Manual   First Owner               23.00  1396.0        90    5.0
# 4       Manual   First Owner               16.10  1298.0      88.2    5.0

# %% [markdown]
# ### Dropping 1 Row
#  We drop the 'Skoda' row

# %%
df_droprow= df.drop(1)
df_droprow.head()
# Out:
#                             name  year  selling_price  km_driven    fuel  \
# 0         Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 2       Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3      Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4         Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# 5  Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000  Petrol
#
#   seller_type transmission        owner  mileage(km/ltr/kg)  engine max_power  \
# 0  Individual       Manual  First Owner               23.40  1248.0        74
# 2  Individual       Manual  Third Owner               17.70  1497.0        78
# 3  Individual       Manual  First Owner               23.00  1396.0        90
# 4  Individual       Manual  First Owner               16.10  1298.0      88.2
# 5  Individual       Manual  First Owner               20.14  1197.0     81.86
#
#    seats
# 0    5.0
# 2    5.0
# 3    5.0
# 4    5.0
# ...

# %%
df_new = pd.read_csv('cardekho.csv')
df_new['selling_price'] = df_new['selling_price']/100000
df_new.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014           4.50     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014           3.70     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006           1.58     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010           2.25     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007           1.30     120000  Petrol
#
#   seller_type transmission         owner  mileage(km/ltr/kg)  engine  \
# 0  Individual       Manual   First Owner               23.40  1248.0
# 1  Individual       Manual  Second Owner               21.14  1498.0
# 2  Individual       Manual   Third Owner               17.70  1497.0
# 3  Individual       Manual   First Owner               23.00  1396.0
# 4  Individual       Manual   First Owner               16.10  1298.0
#
#   max_power  seats
# 0        74    5.0
# 1    103.52    5.0
# 2        78    5.0
# 3        90    5.0
# ...

# %%
df_new=df_new.rename(columns={'selling_price':'selling price in Lakhs' })
df_new.head()
# Out:
#                            name  year  selling price in Lakhs  km_driven  \
# 0        Maruti Swift Dzire VDI  2014                    4.50     145500
# 1  Skoda Rapid 1.5 TDI Ambition  2014                    3.70     120000
# 2      Honda City 2017-2020 EXi  2006                    1.58     140000
# 3     Hyundai i20 Sportz Diesel  2010                    2.25     127000
# 4        Maruti Swift VXI BSIII  2007                    1.30     120000
#
#      fuel seller_type transmission         owner  mileage(km/ltr/kg)  engine  \
# 0  Diesel  Individual       Manual   First Owner               23.40  1248.0
# 1  Diesel  Individual       Manual  Second Owner               21.14  1498.0
# 2  Petrol  Individual       Manual   Third Owner               17.70  1497.0
# 3  Diesel  Individual       Manual   First Owner               23.00  1396.0
# 4  Petrol  Individual       Manual   First Owner               16.10  1298.0
#
#   max_power  seats
# 0        74    5.0
# 1    103.52    5.0
# ...
